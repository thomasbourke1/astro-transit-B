# %% [markdown]
# # Wordcount of Jupyter Notebooks
#
# You can use this notebook to do a wordcount on Coursework B

# %%
##Import needed
import json

# %% [markdown]
# ## Enter the name of the notebook you want to count here
#
# Make sure to run this if you change the filename.

# %%
count_nb = '25190_cwB.ipynb'

# %%
## Loading the data
with open(count_nb) as json_file:
    data = json.load(json_file)

#setting the starting wordcount to 0
wordCount = 0
for each in data['cells']: # Looping over cells
    cellType = each['cell_type']
    if cellType == "markdown": # checking if the cell is markdown
        content = each['source']
        cell_wc = 0 ## starting the cell wordcount
        for line in content: ## looping over lines in cell
            temp = [word for word in line.split() if "#" not in word] # we might need to filter for more markdown keywords here
            wordCount = wordCount + len(temp) ## increasing overall wordcount
            cell_wc += len(temp) ## increasing cell wordcount
        ## Printing info
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        print('')
        print("Cell Starting with: \n %s \n has %i words." %(content[0:2], cell_wc))
        print('')
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
print('')
print("Overall word count in markdown cells is " + str(wordCount))
print('')
print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
print('')
print('Done counting words in notebook %s' %count_nb)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['# Transit analysis of Kepler data from Unknown Star System']
#  has 9 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['<div class="alert alert-block alert-danger">\n', '<b>Candidate number: 25190 </b>\n']
#  has 9 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### Abstract: ']
#  has 1 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['This investigation attempted to analyse data from the Kepler space telescope to detect habitable Earth sized exoplanets. The primary detection method used was the transit method, in which the exoplanets passed in front of the star and periodic drops in the star’s light were measured, like the Moon blocking out the Sun during a solar eclipse. \n', '\n']
#  has 253 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### 1. Introduction:']
#  has 2 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 1.1 What are exoplanets, and why are they important?\n', '\n']
#  has 569 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### 2. Results - Modelling of Kepler lightcurve']
#  has 7 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.1 Total lightcurve']
#  has 3 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['Firstly, the Kepler data were reduced, then masked to remove NaNs (Boolean indexing). They were then normalised with median filter (scipy.medfilt). This was used instead of a mean normalisation as this is less susceptible to outliers. Data were then filtered to remove flux above $ \\mu + 3\\sigma$.']
#  has 48 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.2 Periodogram Analysis']
#  has 3 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['Periodogram analysis was carried out on the data. This only returns **potential** exoplanet candidates. Lomb-Scargle periodogram was used (more suitable for unevely sampled data than FFT). lombscargle() was applied twice, once to identify frequencies present, secondly to remove the effects of aliasing. Spikes in the periodogram represent periodic signals found in the total lightcurve.']
#  has 54 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['Next, tf.period_finder() was used to extract real exoplanet periods. period_finder() sums up multiples of initial planetary period then divides by the number of multiples. Error is taken as $± \\sigma$ of the spread of the given period.\n']
#  has 37 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.3 Lightcurve folding']
#  has 3 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ["The total lightcurve was then folded to periods from period_finder(). The folded lightcurve provides dense lightcurve with overlapping repeated transits. Vicky Scowcroft's function was used to fold lightcurves. Problems now arise as the periods produced by period_finder() don't fold to produce neat lightcurves (shown below). A transit is visible but there is lots of flux data above where the transit is occurring, suggesting the periods determined by period_finder() **aren't accurate enough.**\n"]
#  has 71 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['To solve this, a np.linspace() is created spanning the error in each exoplanet orbital period error. The lightcurves are then judged by eye to see which is folded best. This period is taken as the "true" period.']
#  has 37 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.4.1 Plotting folded lightcurves with modified Gaussian\n', '\n']
#  has 178 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.5 How well did the Gaussian model fit the data?\n', '\n']
#  has 251 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.7 Physical properties:\n', '\n']
#  has 183 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['exoplanet_analyser() was then used to calculate these properties and then to store them in a dictionary. All errors were given to 2 significant figures, then each value was displayed to the same order of precision as each error.']
#  has 38 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 2.8 Transit timing variations:\n', '\n']
#  has 60 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['It was decided that if stellar flux < 0.9995 then this will be marked as a transit. A "snapshot" of data was taken each side of the peak, then the modified Gaussian was fit. Additional filtering was carried out to remove false positives. Repeated measurements of the same transit were also removed.']
#  has 52 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['There is now a list of unsorted transit times. In order to plot the TTVs of each planet, this list will need to be sorted into the three individual exoplanets. \n', '\n']
#  has 52 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ["The depths of Exoplanet 1 and 2 are **too convoluted** to distinguish. An attempt was made to isolate the transits of Exoplant 3, but this didn't work. The next attempt to sort the data is shown below:\n", '\n']
#  has 189 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ["The vlines are irregular, contain gaps and in some cases are too close together. TTVs can't be plotted for data irregularly spaced in this way, so the analysis couldn't be taken further. The main problems were: planets are similar sizes, leading to **similar transit depths**, meaning the data are hard to sort this way."]
#  has 54 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### 3. Discussion\n']
#  has 2 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 3.1 Discussion of main results.']
#  has 5 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['This table shows calculated physical properties for each exoplanet. The key points are as follows: all exoplanets are **more massive** than Earth, are **close** to their host star and have **fast** orbital periods.\n', '\n']
#  has 45 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 3.2 Selection effects']
#  has 3 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['From the NASA exoplanet archive, it can be seen that the modal exoplanet has a mass of 100 ~ 1000 $M_{\\text{earth}}$. These are known as "Hot Jupiters". It\'s almost impossible to detect exoplanets where semi-major axis $> 10AU$ and $ M_{exo} < M_{\\text{earth}}$. These exoplanets are unlikely to be measured by Kepler. Hence it\'s possible there are **more exoplanets** present in the system than the 3 detected.\n']
#  has 67 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### 3.3 Assessing Habitability of detected exoplanets']
#  has 6 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['#### 3.3.2 Mass densities\n', '\n']
#  has 653 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### 4. Summary\n', '\n']
#  has 144 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Cell Starting with:
#  ['### References:\n', '\n']
#  has 104 words.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Overall word count in markdown cells is 3192
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# Done counting words in notebook 25190_cwB.ipynb
